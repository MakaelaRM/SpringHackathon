# %%
# !pip install rasterio
# Out:
# Requirement already satisfied: rasterio in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (1.4.3)
# Requirement already satisfied: affine in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rasterio) (2.4.0)
# Requirement already satisfied: attrs in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rasterio) (23.2.0)
# Requirement already satisfied: certifi in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rasterio) (2025.1.31)
# Requirement already satisfied: click>=4.0 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rasterio) (8.1.8)
# Requirement already satisfied: cligj>=0.5 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rasterio) (0.7.2)
# Requirement already satisfied: numpy>=1.24 in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rasterio) (1.26.4)
# Requirement already satisfied: click-plugins in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rasterio) (1.1.1)
# Requirement already satisfied: pyparsing in /home/ec2-user/anaconda3/envs/tensorflow2_p310/lib/python3.10/site-packages (from rasterio) (3.2.1)

# %%
# 1_data_preparation.ipynb

import rasterio
import numpy as np
import os
import random
import time
from rasterio.warp import reproject, Resampling

# --- Parameters ---
WINDOW_SIZE = 256
NUM_SAMPLES = 100
OUTPUT_DIR = "training_samples"

LIDAR_PATH = "South_Clear_Creek/Lidar_DEM_Hillshade/South_Clear_Creek_BareEarth_DEM_1m.tif"
HILLSHADE_PATH = "South_Clear_Creek/Lidar_DEM_Hillshade/South_Clear_Creek_BareEarth_Hillshade_1m.tif"
NAIP_PATH = "South_Clear_Creek/NAIP/South_Clear_Creek_2023_NAIP_1m.tif"
MASK_PATH = "South_Clear_Creek/Roads_Boundary/South_Clear_Creek_Roads_Mask.tif"

# --- Helper Functions ---
def normalize(image):
    if image.ndim == 3:
        return np.array([normalize(b) for b in image])
    mask = ~np.isnan(image)
    if not np.any(mask):
        return np.zeros_like(image)
    min_val = np.min(image[mask])
    max_val = np.max(image[mask])
    return (image - min_val) / (max_val - min_val) if max_val > min_val else np.zeros_like(image)

def get_random_window(path, size):
    with rasterio.open(path) as src:
        col_off = random.randint(0, max(0, src.width - size))
        row_off = random.randint(0, max(0, src.height - size))
        return rasterio.windows.Window(col_off, row_off, size, size)

def read_band(path, window):
    with rasterio.open(path) as src:
        band = src.read(1, window=window, boundless=True, fill_value=0.0)
    return np.nan_to_num(band, nan=0.0).astype(np.float32)

def read_mask(path, window):
    with rasterio.open(path) as src:
        mask = src.read(1, window=window, boundless=True, fill_value=0)
    return (mask > 0).astype(np.uint8)

def read_and_resample_naip(naip_path, ref_path, window):
    with rasterio.open(ref_path) as ref_src:
        dst_transform = ref_src.window_transform(window)
        dst_crs = ref_src.crs
        dst_width, dst_height = window.width, window.height
        dst_bounds = rasterio.windows.bounds(window, ref_src.transform)

    with rasterio.open(naip_path) as naip_src:
        src_window = rasterio.windows.from_bounds(*dst_bounds, transform=naip_src.transform)
        naip_data = naip_src.read(window=src_window, boundless=True)
        naip_data = np.clip(naip_data, 0, 65535).astype(np.float32) / 65535.0

        resampled = np.empty((naip_data.shape[0], dst_height, dst_width), dtype=np.float32)
        reproject(
            source=naip_data,
            destination=resampled,
            src_transform=naip_src.window_transform(src_window),
            src_crs=naip_src.crs,
            dst_transform=dst_transform,
            dst_crs=dst_crs,
            resampling=Resampling.bilinear
        )
    return resampled

def generate_sample(lidar_path, hillshade_path, naip_path, mask_path, window_size):
    for _ in range(10):  # Try up to 10 times to find a valid (non-empty) mask
        window = get_random_window(lidar_path, window_size)
        lidar = normalize(read_band(lidar_path, window))
        hillshade = normalize(read_band(hillshade_path, window))
        naip = read_and_resample_naip(naip_path, lidar_path, window)
        mask = read_mask(mask_path, window)

        if mask.sum() > 0:  # Only keep patches with road pixels
            x = np.stack([lidar, hillshade, naip[0], naip[1], naip[2]], axis=0)  # (5, H, W)
            y = np.expand_dims(mask, axis=0)  # (1, H, W)
            return x.astype(np.float32), y.astype(np.uint8)

    raise ValueError("❌ No valid mask found after 10 attempts")

def export_samples(lidar_path, hillshade_path, naip_path, mask_path, window_size, output_dir, num_samples=100):
    os.makedirs(output_dir, exist_ok=True)
    start_time = time.time()

    for i in range(num_samples):
        print(f"\n📦 Generating sample {i + 1}/{num_samples}...")
        try:
            x, y = generate_sample(lidar_path, hillshade_path, naip_path, mask_path, window_size)
            np.savez_compressed(os.path.join(output_dir, f"sample_{i:04d}.npz"), x=x, y=y)
            print(f"✅ Saved sample_{i:04d}.npz")
        except Exception as e:
            print(f"⚠️ Skipped sample {i} due to error: {e}")

    print(f"\n⏱️ Completed in {time.time() - start_time:.2f} seconds")

# --- Run the Export ---
export_samples(LIDAR_PATH, HILLSHADE_PATH, NAIP_PATH, MASK_PATH, WINDOW_SIZE, OUTPUT_DIR, NUM_SAMPLES)
# Out:
# 📦 Generating sample 1/100...
# ✅ Saved sample_0000.npz
#
# 📦 Generating sample 2/100...
# ✅ Saved sample_0001.npz
#
# 📦 Generating sample 3/100...
# ⚠️ Skipped sample 2 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 4/100...
# ✅ Saved sample_0003.npz
#
# 📦 Generating sample 5/100...
# ⚠️ Skipped sample 4 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 6/100...
# ✅ Saved sample_0005.npz
#
# 📦 Generating sample 7/100...
# ✅ Saved sample_0006.npz
#
# 📦 Generating sample 8/100...
# ✅ Saved sample_0007.npz
#
# 📦 Generating sample 9/100...
# ✅ Saved sample_0008.npz
#
# 📦 Generating sample 10/100...
# ✅ Saved sample_0009.npz
#
# 📦 Generating sample 11/100...
# ✅ Saved sample_0010.npz
#
# 📦 Generating sample 12/100...
# ✅ Saved sample_0011.npz
#
# 📦 Generating sample 13/100...
# ⚠️ Skipped sample 12 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 14/100...
# ⚠️ Skipped sample 13 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 15/100...
# ✅ Saved sample_0014.npz
#
# 📦 Generating sample 16/100...
# ✅ Saved sample_0015.npz
#
# 📦 Generating sample 17/100...
# ✅ Saved sample_0016.npz
#
# 📦 Generating sample 18/100...
# ✅ Saved sample_0017.npz
#
# 📦 Generating sample 19/100...
# ✅ Saved sample_0018.npz
#
# 📦 Generating sample 20/100...
# ✅ Saved sample_0019.npz
#
# 📦 Generating sample 21/100...
# ✅ Saved sample_0020.npz
#
# 📦 Generating sample 22/100...
# ✅ Saved sample_0021.npz
#
# 📦 Generating sample 23/100...
# ✅ Saved sample_0022.npz
#
# 📦 Generating sample 24/100...
# ✅ Saved sample_0023.npz
#
# 📦 Generating sample 25/100...
# ✅ Saved sample_0024.npz
#
# 📦 Generating sample 26/100...
# ✅ Saved sample_0025.npz
#
# 📦 Generating sample 27/100...
# ✅ Saved sample_0026.npz
#
# 📦 Generating sample 28/100...
# ⚠️ Skipped sample 27 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 29/100...
# ✅ Saved sample_0028.npz
#
# 📦 Generating sample 30/100...
# ✅ Saved sample_0029.npz
#
# 📦 Generating sample 31/100...
# ✅ Saved sample_0030.npz
#
# 📦 Generating sample 32/100...
# ⚠️ Skipped sample 31 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 33/100...
# ✅ Saved sample_0032.npz
#
# 📦 Generating sample 34/100...
# ✅ Saved sample_0033.npz
#
# 📦 Generating sample 35/100...
# ✅ Saved sample_0034.npz
#
# 📦 Generating sample 36/100...
# ✅ Saved sample_0035.npz
#
# 📦 Generating sample 37/100...
# ✅ Saved sample_0036.npz
#
# 📦 Generating sample 38/100...
# ✅ Saved sample_0037.npz
#
# 📦 Generating sample 39/100...
# ⚠️ Skipped sample 38 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 40/100...
# ✅ Saved sample_0039.npz
#
# 📦 Generating sample 41/100...
# ✅ Saved sample_0040.npz
#
# 📦 Generating sample 42/100...
# ✅ Saved sample_0041.npz
#
# 📦 Generating sample 43/100...
# ✅ Saved sample_0042.npz
#
# 📦 Generating sample 44/100...
# ✅ Saved sample_0043.npz
#
# 📦 Generating sample 45/100...
# ✅ Saved sample_0044.npz
#
# 📦 Generating sample 46/100...
# ✅ Saved sample_0045.npz
#
# 📦 Generating sample 47/100...
# ✅ Saved sample_0046.npz
#
# 📦 Generating sample 48/100...
# ✅ Saved sample_0047.npz
#
# 📦 Generating sample 49/100...
# ✅ Saved sample_0048.npz
#
# 📦 Generating sample 50/100...
# ✅ Saved sample_0049.npz
#
# 📦 Generating sample 51/100...
# ✅ Saved sample_0050.npz
#
# 📦 Generating sample 52/100...
# ✅ Saved sample_0051.npz
#
# 📦 Generating sample 53/100...
# ✅ Saved sample_0052.npz
#
# 📦 Generating sample 54/100...
# ✅ Saved sample_0053.npz
#
# 📦 Generating sample 55/100...
# ⚠️ Skipped sample 54 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 56/100...
# ⚠️ Skipped sample 55 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 57/100...
# ✅ Saved sample_0056.npz
#
# 📦 Generating sample 58/100...
# ✅ Saved sample_0057.npz
#
# 📦 Generating sample 59/100...
# ✅ Saved sample_0058.npz
#
# 📦 Generating sample 60/100...
# ✅ Saved sample_0059.npz
#
# 📦 Generating sample 61/100...
# ✅ Saved sample_0060.npz
#
# 📦 Generating sample 62/100...
# ✅ Saved sample_0061.npz
#
# 📦 Generating sample 63/100...
# ✅ Saved sample_0062.npz
#
# 📦 Generating sample 64/100...
# ✅ Saved sample_0063.npz
#
# 📦 Generating sample 65/100...
# ✅ Saved sample_0064.npz
#
# 📦 Generating sample 66/100...
# ✅ Saved sample_0065.npz
#
# 📦 Generating sample 67/100...
# ✅ Saved sample_0066.npz
#
# 📦 Generating sample 68/100...
# ✅ Saved sample_0067.npz
#
# 📦 Generating sample 69/100...
# ✅ Saved sample_0068.npz
#
# 📦 Generating sample 70/100...
# ✅ Saved sample_0069.npz
#
# 📦 Generating sample 71/100...
# ✅ Saved sample_0070.npz
#
# 📦 Generating sample 72/100...
# ⚠️ Skipped sample 71 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 73/100...
# ⚠️ Skipped sample 72 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 74/100...
# ✅ Saved sample_0073.npz
#
# 📦 Generating sample 75/100...
# ✅ Saved sample_0074.npz
#
# 📦 Generating sample 76/100...
# ✅ Saved sample_0075.npz
#
# 📦 Generating sample 77/100...
# ✅ Saved sample_0076.npz
#
# 📦 Generating sample 78/100...
# ✅ Saved sample_0077.npz
#
# 📦 Generating sample 79/100...
# ✅ Saved sample_0078.npz
#
# 📦 Generating sample 80/100...
# ✅ Saved sample_0079.npz
#
# 📦 Generating sample 81/100...
# ✅ Saved sample_0080.npz
#
# 📦 Generating sample 82/100...
# ✅ Saved sample_0081.npz
#
# 📦 Generating sample 83/100...
# ✅ Saved sample_0082.npz
#
# 📦 Generating sample 84/100...
# ⚠️ Skipped sample 83 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 85/100...
# ✅ Saved sample_0084.npz
#
# 📦 Generating sample 86/100...
# ✅ Saved sample_0085.npz
#
# 📦 Generating sample 87/100...
# ✅ Saved sample_0086.npz
#
# 📦 Generating sample 88/100...
# ✅ Saved sample_0087.npz
#
# 📦 Generating sample 89/100...
# ⚠️ Skipped sample 88 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 90/100...
# ✅ Saved sample_0089.npz
#
# 📦 Generating sample 91/100...
# ✅ Saved sample_0090.npz
#
# 📦 Generating sample 92/100...
# ⚠️ Skipped sample 91 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 93/100...
# ✅ Saved sample_0092.npz
#
# 📦 Generating sample 94/100...
# ✅ Saved sample_0093.npz
#
# 📦 Generating sample 95/100...
# ⚠️ Skipped sample 94 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 96/100...
# ⚠️ Skipped sample 95 due to error: ❌ No valid mask found after 10 attempts
#
# 📦 Generating sample 97/100...
# ✅ Saved sample_0096.npz
#
# 📦 Generating sample 98/100...
# ✅ Saved sample_0097.npz
#
# 📦 Generating sample 99/100...
# ✅ Saved sample_0098.npz
#
# 📦 Generating sample 100/100...
# ✅ Saved sample_0099.npz
#
# ⏱️ Completed in 99.50 seconds
